# %%
import pandas as pd

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\eldii\\Documents\\March 0220'

# %%
df=pd.read_csv('../../Downloads/telecom_churn.csv')

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
df.columns=[i.replace(' ','_') for i in df.columns]

# %%
df.head()
# Out:
#   State  Account_length  Area_code International_plan Voice_mail_plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number_vmail_messages  Total_day_minutes  Total_day_calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total_day_charge  Total_eve_minutes  Total_eve_calls  Total_eve_charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account_length          3333 non-null   int64
#  2   Area_code               3333 non-null   int64
#  3   International_plan      3333 non-null   object
#  4   Voice_mail_plan         3333 non-null   object
#  5   Number_vmail_messages   3333 non-null   int64
#  6   Total_day_minutes       3333 non-null   float64
#  7   Total_day_calls         3333 non-null   int64
#  8   Total_day_charge        3333 non-null   float64
#  9   Total_eve_minutes       3333 non-null   float64
#  10  Total_eve_calls         3333 non-null   int64
#  11  Total_eve_charge        3333 non-null   float64
#  12  Total_night_minutes     3333 non-null   float64
#  13  Total_night_calls       3333 non-null   int64
# ...

# %%
df=df.convert_dtypes()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   string
#  1   Account_length          3333 non-null   Int64
#  2   Area_code               3333 non-null   Int64
#  3   International_plan      3333 non-null   string
#  4   Voice_mail_plan         3333 non-null   string
#  5   Number_vmail_messages   3333 non-null   Int64
#  6   Total_day_minutes       3333 non-null   float64
#  7   Total_day_calls         3333 non-null   Int64
#  8   Total_day_charge        3333 non-null   float64
#  9   Total_eve_minutes       3333 non-null   float64
#  10  Total_eve_calls         3333 non-null   Int64
#  11  Total_eve_charge        3333 non-null   float64
#  12  Total_night_minutes     3333 non-null   float64
#  13  Total_night_calls       3333 non-null   Int64
# ...

# %%
df.describe()
# Out:
#        Account_length    Area_code  Number_vmail_messages  Total_day_minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total_day_calls  Total_day_charge  Total_eve_minutes  Total_eve_calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
df.max()
# Out:
# State                        WY
# Account_length              243
# Area_code                   510
# International_plan          Yes
# Voice_mail_plan             Yes
# Number_vmail_messages        51
# Total_day_minutes         350.8
# Total_day_calls             165
# Total_day_charge          59.64
# Total_eve_minutes         363.7
# Total_eve_calls             170
# Total_eve_charge          30.91
# Total_night_minutes         395
# Total_night_calls           175
# Total_night_charge        17.77
# Total_intl_minutes           20
# Total_intl_calls             20
# Total_intl_charge           5.4
# Customer_service_calls        9
# Churn                      True
# dtype: object

# %%
df.mean()
# Out:
# Total_day_minutes      179.775098
# Total_day_charge        30.562307
# Total_eve_minutes      200.980348
# Total_eve_charge        17.083540
# Total_night_minutes    200.872037
# Total_night_charge       9.039325
# Total_intl_minutes      10.237294
# Total_intl_charge        2.764581
# dtype: float64

# %%
df.std()
# Out:
# Total_day_minutes      54.467389
# Total_day_charge        9.259435
# Total_eve_minutes      50.713844
# Total_eve_charge        4.310668
# Total_night_minutes    50.573847
# Total_night_charge      2.275873
# Total_intl_minutes      2.791840
# Total_intl_charge       0.753773
# dtype: float64

# %%
df.var()
# Out:
# Total_day_minutes      2966.696487
# Total_day_charge         85.737128
# Total_eve_minutes      2571.894016
# Total_eve_charge         18.581856
# Total_night_minutes    2557.714002
# Total_night_charge        5.179597
# Total_intl_minutes        7.794368
# Total_intl_charge         0.568173
# dtype: float64

# %%
df.loc[df.Total_eve_charge.idxmax()]
# Out:
# State                        NC
# Account_length              130
# Area_code                   408
# International_plan          Yes
# Voice_mail_plan              No
# Number_vmail_messages         0
# Total_day_minutes         216.2
# Total_day_calls             106
# Total_day_charge          36.75
# Total_eve_minutes         363.7
# Total_eve_calls              86
# Total_eve_charge          30.91
# Total_night_minutes       126.7
# Total_night_calls           123
# Total_night_charge          5.7
# Total_intl_minutes         16.9
# Total_intl_calls              2
# Total_intl_charge          4.56
# Customer_service_calls        5
# Churn                      True
# Name: 2732, dtype: object

# %%
df.mode()
# Out:
#   State  Account_length  Area_code International_plan Voice_mail_plan  \
# 0    WV             105        415                 No              No
# 1  <NA>            <NA>       <NA>               <NA>            <NA>
# 2  <NA>            <NA>       <NA>               <NA>            <NA>
# 3  <NA>            <NA>       <NA>               <NA>            <NA>
# 4  <NA>            <NA>       <NA>               <NA>            <NA>
#
#    Number_vmail_messages  Total_day_minutes  Total_day_calls  \
# 0                      0              154.0              102
# 1                   <NA>              159.5             <NA>
# 2                   <NA>              174.5             <NA>
# 3                   <NA>                NaN             <NA>
# 4                   <NA>                NaN             <NA>
#
#    Total_day_charge  Total_eve_minutes  Total_eve_calls  Total_eve_charge  \
# 0             26.18              169.9              105             14.25
# ...

# %%
df.quantile(0.4)
# Out:
# Account_length                91
# Area_code                    415
# Number_vmail_messages          0
# Total_day_minutes         165.68
# Total_day_calls               96
# Total_day_charge          28.166
# Total_eve_minutes            188
# Total_eve_calls               95
# Total_eve_charge           15.98
# Total_night_minutes        188.2
# Total_night_calls             95
# Total_night_charge          8.47
# Total_intl_minutes           9.7
# Total_intl_calls               3
# Total_intl_charge           2.62
# Customer_service_calls         1
# Name: 0.4, dtype: object

# %%
df.quantile(0.94)
# Out:
# Account_length                163
# Area_code                     510
# Number_vmail_messages          35
# Total_day_minutes         265.908
# Total_day_calls            131.08
# Total_day_charge          45.2016
# Total_eve_minutes           278.6
# Total_eve_calls               131
# Total_eve_charge            23.68
# Total_night_minutes         279.8
# Total_night_calls             130
# Total_night_charge          12.59
# Total_intl_minutes           14.4
# Total_intl_calls                9
# Total_intl_charge            3.89
# Customer_service_calls          4
# Name: 0.94, dtype: object

# %%
# %matplotlib inline

# %%
df.Total_intl_calls.plot()

# %%
df.Total_intl_calls.hist()
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\eldii\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3296, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-19-0ca9dd09cdb0>", line 1, in <module>
#     df.Total_intl_calls.hist()
#   File "C:\Users\eldii\Anaconda3\lib\site-packages\pandas\plotting\_core.py", line 85, in hist_series
#     **kwargs,
#   File "C:\Users\eldii\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\hist.py", line 309, in hist_series
#     ax.hist(values, bins=bins, **kwds)
#   File "C:\Users\eldii\Anaconda3\lib\site-packages\matplotlib\__init__.py", line 1810, in inner
#     return func(ax, *args, **kwargs)
#   File "C:\Users\eldii\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py", line 6667, in hist
#     color=c, **{bottom_kwarg: bottom})
# ...

# %%
df.Total_day_minutes.hist()

# %%
import seaborn as sns

# %%
sns.distplot(a=df['Total_day_minutes'].values)

# %%
df.Total_day_minutes.plot.box()

# %%
sns.violinplot(data=df, x='Total_day_minutes')

# %% [markdown]
# # Specific Pandas

# %%
df.Total_day_calls>df.Total_night_calls
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 3328    False
# 3329    False
# 3330     True
# 3331    False
# 3332     True
# Length: 3333, dtype: boolean

# %%
df.eval('Total_day_calls-Total_night_calls')
# Out:
# 0       19
# 1       20
# 2       10
# 3      -18
# 4       -8
#         ..
# 3328    -6
# 3329   -66
# 3330    18
# 3331   -32
# 3332    36
# Length: 3333, dtype: int64

# %%
df.eval('Total_day_calls*24-11>160')
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 3328    True
# 3329    True
# 3330    True
# 3331    True
# 3332    True
# Length: 3333, dtype: bool

# %%
exec('x=11')

# %%
x
# Out:
# 11

# %%
exec('x=x*2')

# %%
x
# Out:
# 22

# %%
d=eval("{'d':11}")

# %%
d
# Out:
# {'d': 11}

# %%
df.query('Total_day_calls*24-11>160')
# Out:
#      State  Account_length  Area_code International_plan Voice_mail_plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number_vmail_messages  Total_day_minutes  Total_day_calls  \
# ...

# %%
df.eval('Account_length>Account_length.quantile(0.9)')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3328     True
# 3329    False
# 3330    False
# 3331     True
# 3332    False
# Length: 3333, dtype: bool

# %%
df.query('Account_length>Account_length.quantile(0.9)')
# Out:
#      State  Account_length  Area_code International_plan Voice_mail_plan  \
# 12      IA             168        408                 No              No
# 15      NY             161        415                 No              No
# 25      NE             174        415                 No              No
# 32      LA             172        408                 No              No
# 43      ID             160        415                 No              No
# ...    ...             ...        ...                ...             ...
# 3312    SC             181        408                 No              No
# 3317    SD             163        415                Yes              No
# 3324    WV             159        415                 No              No
# 3328    AZ             192        415                 No             Yes
# 3331    CT             184        510                Yes              No
#
#       Number_vmail_messages  Total_day_minutes  Total_day_calls  \
# ...

# %%
df[df['Account_length']>df.Account_length.quantile(0.9)]
# Out:
#      State  Account_length  Area_code International_plan Voice_mail_plan  \
# 12      IA             168        408                 No              No
# 15      NY             161        415                 No              No
# 25      NE             174        415                 No              No
# 32      LA             172        408                 No              No
# 43      ID             160        415                 No              No
# ...    ...             ...        ...                ...             ...
# 3312    SC             181        408                 No              No
# 3317    SD             163        415                Yes              No
# 3324    WV             159        415                 No              No
# 3328    AZ             192        415                 No             Yes
# 3331    CT             184        510                Yes              No
#
#       Number_vmail_messages  Total_day_minutes  Total_day_calls  \
# ...

# %%
import numpy as np

# %%
seasons=pd.DataFrame(np.random.random((10,4)),columns=['winter','spring','summer','fall'])

# %%
seasons
# Out:
#      winter    spring    summer      fall
# 0  0.648611  0.679044  0.989759  0.615318
# 1  0.029292  0.765106  0.212753  0.330159
# 2  0.051152  0.045078  0.775525  0.024435
# 3  0.575505  0.770601  0.717122  0.780490
# 4  0.907027  0.478044  0.102151  0.908000
# 5  0.188249  0.005216  0.854900  0.644298
# 6  0.911491  0.667110  0.275415  0.083564
# 7  0.316898  0.233093  0.903193  0.422942
# 8  0.395673  0.590509  0.144054  0.818693
# 9  0.710994  0.875187  0.714942  0.268522

# %%
seasons=seasons.round(2)
seasons
# Out:
#    winter  spring  summer  fall
# 0    0.65    0.68    0.99  0.62
# 1    0.03    0.77    0.21  0.33
# 2    0.05    0.05    0.78  0.02
# 3    0.58    0.77    0.72  0.78
# 4    0.91    0.48    0.10  0.91
# 5    0.19    0.01    0.85  0.64
# 6    0.91    0.67    0.28  0.08
# 7    0.32    0.23    0.90  0.42
# 8    0.40    0.59    0.14  0.82
# 9    0.71    0.88    0.71  0.27

# %%
lookup_elements=['winter','spring','summer','fall','winter','winter','spring','summer','fall','winter']

# %%
seasons.lookup(seasons.index,lookup_elements)
# Out:
# array([0.65, 0.77, 0.78, 0.78, 0.91, 0.19, 0.67, 0.9 , 0.82, 0.71])

# %%
seasons.lookup([0,9],['winter','spring'])
# Out:
# array([0.65, 0.88])
